# %%
import torch
import pandas as pd 
import numpy as np 
import altair as alt 
torch.__version__


import os
from gym_runner import GymRunner
from q_func_approx import QualityFuncApprox
from sarsa_agent import SarsaAgent
from grid_search import GridSearch

# %%
param_grid = dict(
    alpha=np.logspace(-6, -2, 10),
    gamma=np.linspace(.9, .99, 5),
    epsilon_decay=np.linspace(.997, .999, 5),
)
param_grid_small = dict(
    alpha=np.logspace(-6, -2, 5),
    gamma=np.linspace(.9, .99, 4),
)

gs = GridSearch(
    agent = SarsaAgent, 
    Q = QualityFuncApprox, 
    runner = GymRunner,
    env_id = "CartPole-v1", 
    param_grid = param_grid)

# %%
results = gs.fit()

# %%
results.sort_values('mean_score')
# Out:
#         alpha  epsilon_decay   gamma  mean_score  max_mean_score
# 147  0.000167         0.9990  0.9450         8.4               9
# 156  0.000464         0.9975  0.9225         8.6               9
# 113  0.000060         0.9980  0.9675         8.6              10
# 169  0.000464         0.9985  0.9900         8.8              10
# 144  0.000167         0.9985  0.9900         8.8              10
# ..        ...            ...     ...         ...             ...
# 226  0.010000         0.9970  0.9225       243.2             500
# 216  0.003594         0.9985  0.9225       243.8             500
# 206  0.003594         0.9975  0.9225       268.4             500
# 237  0.010000         0.9980  0.9450       280.8             500
# 212  0.003594         0.9980  0.9450       303.8             500
#
# [250 rows x 5 columns]
